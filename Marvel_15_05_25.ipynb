# %% [markdown]
# Jaume Alcobe

# %%
import pandas as pd
marvel=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/marvel_clean[1].txt")
marvel
# Out:
#                                         Title  \
# 0                             Howard the Duck
# 1                                       Blade
# 2                                       X-Men
# 3                                    Blade II
# 4                                  Spider-Man
# ..                                        ...
# 59                                Black Widow
# 60  Shang-Chi and the Legend of the Ten Rings
# 61                Venom: Let There Be Carnage
# 62                                   Eternals
# 63                    Spider-Man: No Way Home
#
#                             Distributor        ReleaseDateUS     Budget  \
# 0                    Universal Pictures  1986-08-01 00:00:00   37000000
# 1                       New Line Cinema  1998-08-21 00:00:00   45000000
# 2                      20th Century Fox  2000-07-14 00:00:00   75000000
# 3                       New Line Cinema  2002-03-22 00:00:00   54000000
# ...

# %%
marvel.head(10)
# Out:
#              Title         Distributor        ReleaseDateUS     Budget  \
# 0  Howard the Duck  Universal Pictures  1986-08-01 00:00:00   37000000
# 1            Blade     New Line Cinema  1998-08-21 00:00:00   45000000
# 2            X-Men    20th Century Fox  2000-07-14 00:00:00   75000000
# 3         Blade II     New Line Cinema  2002-03-22 00:00:00   54000000
# 4       Spider-Man       Sony Pictures  2002-05-03 00:00:00  139000000
# 5        Daredevil    20th Century Fox  2003-02-14 00:00:00   78000000
# 6               X2    20th Century Fox  2003-05-02 00:00:00  110000000
# 7             Hulk  Universal Pictures  2003-06-20 00:00:00  137000000
# 8     The Punisher     Lionsgate Films  2004-04-16 00:00:00   33000000
# 9     Spider-Man 2       Sony Pictures  2004-06-30 00:00:00  200000000
#
#    OpeningWeekendNorthAmerica  NorthAmerica  OtherTerritories  Worldwide
# 0                     5070136      16295774          21667000   37962774
# ...

# %%
marvel.tail()
# Out:
#                                         Title  \
# 59                                Black Widow
# 60  Shang-Chi and the Legend of the Ten Rings
# 61                Venom: Let There Be Carnage
# 62                                   Eternals
# 63                    Spider-Man: No Way Home
#
#                             Distributor        ReleaseDateUS     Budget  \
# 59  Walt Disney Studios Motion Pictures  2021-07-09 00:00:00  200000000
# 60  Walt Disney Studios Motion Pictures  2021-09-03 00:00:00  150000000
# 61                        Sony Pictures  2021-10-01 00:00:00  110000000
# 62  Walt Disney Studios Motion Pictures  2021-11-05 00:00:00  200000000
# 63                        Sony Pictures  2021-12-17 00:00:00  200000000
#
#     OpeningWeekendNorthAmerica  NorthAmerica  OtherTerritories   Worldwide
# 59                    80366312     183651665         195979696   379631351
# 60                    75388688     224543292         207700000   432243292
# ...

# %%
marvel.columns
# Out:
# Index(['Title', 'Distributor', 'ReleaseDateUS', 'Budget',
#        'OpeningWeekendNorthAmerica', 'NorthAmerica', 'OtherTerritories',
#        'Worldwide'],
#       dtype='object')

# %%
marvel.info() #La info de la base de datos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Title                       64 non-null     object
#  1   Distributor                 64 non-null     object
#  2   ReleaseDateUS               64 non-null     object
#  3   Budget                      64 non-null     int64
#  4   OpeningWeekendNorthAmerica  64 non-null     int64
#  5   NorthAmerica                64 non-null     int64
#  6   OtherTerritories            64 non-null     int64
#  7   Worldwide                   64 non-null     int64
# dtypes: int64(5), object(3)
# memory usage: 4.1+ KB

# %%
marvel = marvel.drop(columns=["NorthAmerica", "OtherTerritories"])
marvel.head()
# Out:
#              Title         Distributor        ReleaseDateUS     Budget  \
# 0  Howard the Duck  Universal Pictures  1986-08-01 00:00:00   37000000
# 1            Blade     New Line Cinema  1998-08-21 00:00:00   45000000
# 2            X-Men    20th Century Fox  2000-07-14 00:00:00   75000000
# 3         Blade II     New Line Cinema  2002-03-22 00:00:00   54000000
# 4       Spider-Man       Sony Pictures  2002-05-03 00:00:00  139000000
#
#    OpeningWeekendNorthAmerica  Worldwide
# 0                     5070136   37962774
# 1                    17073856  131183530
# 2                    54471475  296339527
# 3                    32528016  155010032
# 4                   114844116  821708551

# %%
marvel.rename(columns = {'OpeningWeekendNorthAmerica':"Opening"}, inplace=True )

# %%
marvel
# Out:
#                                         Title  \
# 0                             Howard the Duck
# 1                                       Blade
# 2                                       X-Men
# 3                                    Blade II
# 4                                  Spider-Man
# ..                                        ...
# 59                                Black Widow
# 60  Shang-Chi and the Legend of the Ten Rings
# 61                Venom: Let There Be Carnage
# 62                                   Eternals
# 63                    Spider-Man: No Way Home
#
#                             Distributor        ReleaseDateUS     Budget  \
# 0                    Universal Pictures  1986-08-01 00:00:00   37000000
# 1                       New Line Cinema  1998-08-21 00:00:00   45000000
# 2                      20th Century Fox  2000-07-14 00:00:00   75000000
# 3                       New Line Cinema  2002-03-22 00:00:00   54000000
# ...

# %%
marvel.iloc[4]
# Out:
# Title                     Spider-Man
# Distributor            Sony Pictures
# ReleaseDateUS    2002-05-03 00:00:00
# Budget                     139000000
# Opening                    114844116
# Worldwide                  821708551
# Name: 4, dtype: object

# %% [markdown]
# ##Otra forma de escoger columnas:

# %%
marvel
# Out:
#                                         Title  \
# 0                             Howard the Duck
# 1                                       Blade
# 2                                       X-Men
# 3                                    Blade II
# 4                                  Spider-Man
# ..                                        ...
# 59                                Black Widow
# 60  Shang-Chi and the Legend of the Ten Rings
# 61                Venom: Let There Be Carnage
# 62                                   Eternals
# 63                    Spider-Man: No Way Home
#
#                             Distributor        ReleaseDateUS     Budget  \
# 0                    Universal Pictures  1986-08-01 00:00:00   37000000
# 1                       New Line Cinema  1998-08-21 00:00:00   45000000
# 2                      20th Century Fox  2000-07-14 00:00:00   75000000
# 3                       New Line Cinema  2002-03-22 00:00:00   54000000
# ...

# %%
spidey = marvel.iloc[4]
spidey
# Out:
# Title                     Spider-Man
# Distributor            Sony Pictures
# ReleaseDateUS    2002-05-03 00:00:00
# Budget                     139000000
# Opening                    114844116
# Worldwide                  821708551
# Name: 4, dtype: object

# %%
spidey.iloc[1]
# Out:
# 'Sony Pictures'

# %%
type(spidey)
# Out:
# pandas.core.series.Series

# %%
import pandas as pd
# Crear el DataFrame
data = {
    'Columna1': [10, 20, 30],
    'Columna2': ['A', 'B', 'C'],
    'Columna3': [1.5, 2.5, 3.5],
    'Columna4': [True, False, True],
    'Columna5': ['X', 'Y', 'Z']
}

df = pd.DataFrame(data)
df.T

# %%
marvel
# Out:
#                                         Title  \
# 0                             Howard the Duck
# 1                                       Blade
# 2                                       X-Men
# 3                                    Blade II
# 4                                  Spider-Man
# ..                                        ...
# 59                                Black Widow
# 60  Shang-Chi and the Legend of the Ten Rings
# 61                Venom: Let There Be Carnage
# 62                                   Eternals
# 63                    Spider-Man: No Way Home
#
#                             Distributor        ReleaseDateUS     Budget  \
# 0                    Universal Pictures  1986-08-01 00:00:00   37000000
# 1                       New Line Cinema  1998-08-21 00:00:00   45000000
# 2                      20th Century Fox  2000-07-14 00:00:00   75000000
# 3                       New Line Cinema  2002-03-22 00:00:00   54000000
# ...

# %%
#De acuerdo al Budget, vamos a ver qué películas tienen más que spidey
marvel['Budget']
# Out:
# 0      37000000
# 1      45000000
# 2      75000000
# 3      54000000
# 4     139000000
#         ...
# 59    200000000
# 60    150000000
# 61    110000000
# 62    200000000
# 63    200000000
# Name: Budget, Length: 64, dtype: int64

# %%
#De acuerdo al Budget, vamos a ver qué películas tienen más que spidey
marvel['Budget'] > 139000000
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 59     True
# 60     True
# 61    False
# 62     True
# 63     True
# Name: Budget, Length: 64, dtype: bool

# %%
marvel_budget = marvel[marvel['Budget'] >= 139000000]

# %%
marvel_budget = marvel_budget.sort_values(by="Budget", ascending = False)

# %%
marvel_budget.groupby("Budget").max()
# Out:
#                                 Title                          Distributor  \
# Budget
# 139000000                  Spider-Man                        Sony Pictures
# 140000000                    Iron Man                   Paramount Pictures
# 150000000    X-Men Origins: Wolverine  Walt Disney Studios Motion Pictures
# 152000000              Captain Marvel  Walt Disney Studios Motion Pictures
# 160000000          X-Men: First Class                        Sony Pictures
# 162000000        Ant-Man and the Wasp  Walt Disney Studios Motion Pictures
# 165000000              Doctor Strange  Walt Disney Studios Motion Pictures
# 170000000        Thor: The Dark World  Walt Disney Studios Motion Pictures
# 175000000      Spider-Man: Homecoming                        Sony Pictures
# 178000000           X-Men: Apocalypse                     20th Century Fox
# 180000000              Thor: Ragnarok  Walt Disney Studios Motion Pictures
# ...
